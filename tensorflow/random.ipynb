# %%
from numpy import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

x = random.randint(100)

print(x)
# Out:
# 20

# %%
x = random.rand(3, 2)

print(x)
# Out:
# [[0.43321124 0.63957544]
#  [0.45988984 0.42358209]
#  [0.60313525 0.56631337]]

# %%
x = random.choice([3, 5, 7, 9, 12], size = (3, 5))

print(x)
# Out:
# [[ 5  3  5 12  5]
#  [ 7  5  9  7  7]
#  [ 5 12  3 12  5]]

# %%
x = random.randint(100, size=(5))

print(x)
# Out:
# [11 95 29 97 44]

# %%
arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)

print(random.permutation(arr))
# Out:
# [2 5 3 1 4]
# [2 4 5 1 3]

# %%
sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
plt.show()
# Out:
# C:\Users\kamil\AppData\Local\Temp\ipykernel_36880\2878133669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))

x = x.flatten()

sns.displot(x, kde=True)
# Out:
# c:\Users\kamil\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
